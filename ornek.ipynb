# %%
import pandas as pd

df = pd.read_csv("CEAS_08.csv")
df.head(10)
# Out:
#                                               sender  \
# 0                   Young Esposito <Young@iworld.de>
# 1                       Mok <ipline's1983@icable.ph>
# 2  Daily Top 10 <Karmandeep-opengevl@universalnet...
# 3                 Michael Parker <ivqrnai@pobox.com>
# 4  Gretchen Suggs <externalsep1@loanofficertool.com>
# 5  Caroline Aragon <dwthaidomainnamesm@thaidomain...
# 6    Replica Watches <jhorton@thebakercompanies.com>
# 7             Daily Top 10 <acidirev_1972@tcwpg.com>
# 8                  qydlqcws-iacfym@issues.apache.org
# 9      Daily Top 10 <orn|dent_1973@musicaedischi.it>
#
#                                          receiver  \
# 0                     user4@gvc.ceas-challenge.cc
# 1                   user2.2@gvc.ceas-challenge.cc
# 2                   user2.9@gvc.ceas-challenge.cc
# 3  SpamAssassin Dev <xrh@spamassassin.apache.org>
# 4                   user2.2@gvc.ceas-challenge.cc
# 5                user7-ext5@gvc.ceas-challenge.cc
# ...

# %%
import pandas as pd

df = pd.read_csv("Enron.csv")
df.head(10)
# Out:
#                                       subject  \
# 0                   hpl nom for may 25 , 2001
# 1            re : nom / actual vols for 24 th
# 2  enron actuals for march 30 - april 1 , 201
# 3                   hpl nom for may 30 , 2001
# 4                   hpl nom for june 1 , 2001
# 5                     hpl nom for may 31 2001
# 6                                      # 9760
# 7             hpl noms for february 15 , 2000
# 8              fw : pooling contract template
# 9                 hpl nom for march 28 , 2000
#
#                                                 body  label
# 0  ( see attached file : hplno 525 . xls )\n- hpl...      0
# 1  - - - - - - - - - - - - - - - - - - - - - - fo...      0
# 2  estimated actuals\nmarch 30 , 2001\nno flow\nm...      0
# 3  ( see attached file : hplno 530 . xls )\n- hpl...      0
# 4  ( see attached file : hplno 601 . xls )\n- hpl...      0
# 5  ( see attached file : hplno 531 . xls )\n- hpl...      0
# ...

# %%
import pandas as pd

df = pd.read_csv("Ling.csv")
df.head(10)
# Out:
#                                              subject  \
# 0            job posting - apple-iss research center
# 1                                                NaN
# 2  query : letter frequencies for text identifica...
# 3                                               risk
# 4                           request book information
# 5  call for abstracts : optimality in syntactic t...
# 6                m . a . in scandinavian linguistics
# 7  call for papers : linguistics session of the m...
# 8                    foreign language in commercials
# 9  fulbright announcement : please post / dissemi...
#
#                                                 body  label
# 0  content - length : 3386 apple-iss research cen...      0
# 1  lang classification grimes , joseph e . and ba...      0
# 2  i am posting this inquiry for sergei atamas ( ...      0
# 3  a colleague and i are researching the differin...      0
# 4  earlier this morning i was on the phone with a...      0
# ...

# %%
import pandas as pd

df = pd.read_csv("Nazario_5.csv")
df.head(10)
# Out:
#                                               sender  \
# 0                 "Hu, Sylvia" <Sylvia.Hu@ENRON.com>
# 1                   "Webb, Jay" <Jay.Webb@ENRON.com>
# 2               "Symms, Mark" <Mark.Symms@ENRON.com>
# 3             "Thorne, Judy" <Judy.Thorne@ENRON.com>
# 4  "Williams, Jason R (Credit)" <Jason.R.Williams...
# 5             "Thorne, Judy" <Judy.Thorne@ENRON.com>
# 6         "Brennan, Lorna" <Lorna.Brennan@ENRON.com>
# 7                   "Shah, Kal" <Kal.Shah@ENRON.com>
# 8                   "Shah, Kal" <Kal.Shah@ENRON.com>
# 9         "Gimble, Mathew" <Mathew.Gimble@ENRON.com>
#
#                                             receiver  \
# 0  "Acevedo, Felecia" <Felecia.Acevedo@ENRON.com>...
# 1           "Lambie, Chris" <Chris.Lambie@ENRON.com>
# 2        "Thomas, Paul D." <Paul.D.Thomas@ENRON.com>
# 3  "Grass, John" <John.Grass@ENRON.com>, "Nemec, ...
# 4  "Nemec, Gerald" <Gerald.Nemec@ENRON.com>, "Dic...
# 5  "Hodge, Jeffrey T." <Jeffrey.T.Hodge@ENRON.com...
# ...

# %%
import pandas as pd

df = pd.read_csv("Nazario.csv")
df.head(10)
# Out:
#                                               sender  \
# 0  Mail System Internal Data <MAILER-DAEMON@monke...
# 1                        cPanel <service@cpanel.com>
# 2    Microsoft Outlook <recepcao@unimedceara.com.br>
# 3                     Ann Garcia <AnGarcia@mcoe.org>
# 4                 "USAA" <usaaacctupdate@sccu4u.com>
# 5          =?utf-8?Q?P=2eSupport?= <infos@2015p.com>
# 6                                             Update
# 7                  "USAA" <usaa-offers@banking2.org>
# 8      "Tourne, Michele" <MTourne@co.humboldt.ca.us>
# 9  "English, Saundra (FDNY)" <Saundra.English@fdn...
#
#                                  receiver  \
# 0                                     NaN
# 1                         jose@monkey.org
# 2                                     NaN
# 3     "info@maaaaa.org" <info@maaaaa.org>
# 4  Recipients <usaaacctupdate@sccu4u.com>
# 5                         jose@monkey.org
# 6                              Recipients
# ...

# %%
import pandas as pd

df = pd.read_csv("Nigerian_Fraud.csv")
df.head(10)
# Out:
#                                             sender              receiver  \
# 0   MR. JAMES NGOLA. <james_ngola2002@maktoob.com>  webmaster@aclweb.org
# 1   Mr. Ben Suleman <bensul2004nng@spinfinder.com>                   R@M
# 2        PRINCE OBONG ELEME <obong_715@epatra.com>  webmaster@aclweb.org
# 3        PRINCE OBONG ELEME <obong_715@epatra.com>  webmaster@aclweb.org
# 4               Maryam Abacha <m_abacha03@www.com>                   R@M
# 5              Kuta David <davidkuta@postmark.net>   davidkuta@yahoo.com
# 6  Barrister tunde dosumu <tunde_dosumu@lycos.com>                   NaN
# 7   William Drallo <william2244drallo@maktoob.com>  webmaster@aclweb.org
# 8        MR USMAN ABDUL <abdul_817@rediffmail.com>                   R@M
# 9            Tunde Dosumu <barrister_td@lycos.com>                   NaN
#
#                               date  \
# 0  Thu, 31 Oct 2002 02:38:20 +0000
# 1  Thu, 31 Oct 2002 05:10:00 -0000
# 2  Thu, 31 Oct 2002 22:17:55 +0100
# ...

# %%
import pandas as pd

df = pd.read_csv("parafraz_phishing_dataset.csv")
df.head(10)
# Out:
#                                                 text  label      type  \
# 0  Login from an unknown location detected on you...      1  parafraz
# 1  Tax documents are pending. Submit your informa...      1  parafraz
# 2  Your PayPal profile has been limited due to su...      1  parafraz
# 3  Tax documents are pending. Submit your informa...      1  parafraz
# 4  Security alert from Microsoft. Unrecognized si...      1  parafraz
# 5  Your password has expired. Update it now to co...      1  parafraz
# 6  Your bill is overdue. Make a payment to avoid ...      1  parafraz
# 7  Billing failure on your Netflix profile. Pleas...      1  parafraz
# 8  Login from an unknown location detected on you...      1  parafraz
# 9  Your bill is overdue. Make a payment to avoid ...      1  parafraz
#
#               source
# 0  chatgpt_rewritten
# 1  chatgpt_rewritten
# 2  chatgpt_rewritten
# 3  chatgpt_rewritten
# 4  chatgpt_rewritten
# 5  chatgpt_rewritten
# 6  chatgpt_rewritten
# ...

# %%
import pandas as pd

df = pd.read_csv("real_phishing_dataset.csv")
df.head(10)
# Out:
#                                                 text  label  type source
# 0  hpl nom for may 25 , 2001 ( see attached file ...    0.0  real  enron
# 1  re : nom / actual vols for 24 th - - - - - - -...    0.0  real  enron
# 2  enron actuals for march 30 - april 1 , 201 est...    0.0  real  enron
# 3  hpl nom for may 30 , 2001 ( see attached file ...    0.0  real  enron
# 4  hpl nom for june 1 , 2001 ( see attached file ...    0.0  real  enron
# 5  hpl nom for may 31 2001 ( see attached file : ...    0.0  real  enron
# 6  # 9760 tried to get fancy with your address an...    0.0  real  enron
# 7  hpl noms for february 15 , 2000 ( see attached...    0.0  real  enron
# 8  fw : pooling contract template - - - - - origi...    0.0  real  enron
# 9  hpl nom for march 28 , 2000 ( see attached fil...    0.0  real  enron

# %%
import pandas as pd

df = pd.read_csv("SpamAssasin.csv")
df.head(10)
# Out:
#                                            sender  \
# 0                  Robert Elz <kre@munnari.OZ.AU>
# 1       Steve Burt <Steve_Burt@cursor-system.com>
# 2                   "Tim Chapman" <timc@2ubh.com>
# 3                Monty Solomon <monty@roscom.com>
# 4       Stewart Smith <Stewart.Smith@ee.ed.ac.uk>
# 5     "Martin Adamson" <martin@srv0.ems.ed.ac.uk>
# 6     "Martin Adamson" <martin@srv0.ems.ed.ac.uk>
# 7       Stewart Smith <Stewart.Smith@ee.ed.ac.uk>
# 8     "Martin Adamson" <martin@srv0.ems.ed.ac.uk>
# 9  "NOI Administrator" <admin@networksonline.com>
#
#                                             receiver  \
# 0  Chris Garrigues <cwg-dated-1030377287.06fa6d@D...
# 1  "'zzzzteana@yahoogroups.com'" <zzzzteana@yahoo...
# 2              zzzzteana <zzzzteana@yahoogroups.com>
# 3                           undisclosed-recipient: ;
# 4                          zzzzteana@yahoogroups.com
# 5                          zzzzteana@yahoogroups.com
# ...

# %%
import pandas as pd

df = pd.read_csv("synthetic_phishing_dataset.csv")
df.head(10)
# Out:
#                                                 text  label       type  \
# 0  Security Alert: Someone tried accessing your P...      1  synthetic
# 1  We noticed suspicious login activity on your P...      1  synthetic
# 2  We noticed suspicious login activity on your M...      1  synthetic
# 3  Urgent: Your account with Apple will be deacti...      1  synthetic
# 4  Your Apple account has been suspended. Click h...      1  synthetic
# 5  Urgent: Your account with Netflix will be deac...      1  synthetic
# 6  Tax Notice: You are eligible for a refund. Con...      1  synthetic
# 7  Your Dropbox account has been suspended. Click...      1  synthetic
# 8  Salesforce has flagged your account for unusua...      1  synthetic
# 9  Salesforce has flagged your account for unusua...      1  synthetic
#
#               source
# 0  chatgpt_generated
# 1  chatgpt_generated
# 2  chatgpt_generated
# 3  chatgpt_generated
# 4  chatgpt_generated
# 5  chatgpt_generated
# 6  chatgpt_generated
# ...

# %%
import pandas as pd

df = pd.read_csv("TREC_05.csv", engine="python", on_bad_lines="skip")
df.head(10)
# Out:
#                                               sender  \
# 0                 "Hu, Sylvia" <Sylvia.Hu@ENRON.com>
# 1                   "Webb, Jay" <Jay.Webb@ENRON.com>
# 2               "Symms, Mark" <Mark.Symms@ENRON.com>
# 3             "Thorne, Judy" <Judy.Thorne@ENRON.com>
# 4  "Williams, Jason R (Credit)" <Jason.R.Williams...
# 5             "Thorne, Judy" <Judy.Thorne@ENRON.com>
# 6         "Brennan, Lorna" <Lorna.Brennan@ENRON.com>
# 7                   "Shah, Kal" <Kal.Shah@ENRON.com>
# 8                   "Shah, Kal" <Kal.Shah@ENRON.com>
# 9         "Gimble, Mathew" <Mathew.Gimble@ENRON.com>
#
#                                             receiver  \
# 0  "Acevedo, Felecia" <Felecia.Acevedo@ENRON.com>...
# 1           "Lambie, Chris" <Chris.Lambie@ENRON.com>
# 2        "Thomas, Paul D." <Paul.D.Thomas@ENRON.com>
# 3  "Grass, John" <John.Grass@ENRON.com>, "Nemec, ...
# 4  "Nemec, Gerald" <Gerald.Nemec@ENRON.com>, "Dic...
# 5  "Hodge, Jeffrey T." <Jeffrey.T.Hodge@ENRON.com...
# ...

# %%
import pandas as pd

df = pd.read_csv("TREC_06.csv", engine="python", on_bad_lines="skip")
df.head(10)
# Out:
#                                          sender  \
# 0                    jhpb@sarto.budd-lake.nj.us
# 1            Stella Lowry <rookcuduq@yahoo.com>
# 2       Walter <trwmpca@downtowncumberland.com>
# 3  Scott Schwartz <schwartz@groucho.cs.psu.edu>
# 4   Mr Jailyn Koepke <kiflsbizc@attheworld.com>
# 5  Scott Schwartz <schwartz@groucho.cs.psu.edu>
# 6                  mike@majestix.cs.uoregon.edu
# 7           Jody Gee <cdysd@kodiakcomputer.com>
# 8            Dana Arroyo <confirm@1000land.com>
# 9         Austin Sullivan <rngwmlw@autojobs.nl>
#
#                              receiver                             date  \
# 0                                 NaN  Tue, 28 Jul 1992 03:13:55 +0000
# 1  Brian <bernice@groucho.cs.psu.edu>  Sat, 03 Apr 1993 10:34:36 -0500
# 2           arline@groucho.cs.psu.edu  Tue, 06 Apr 1993 20:33:13 -0600
# 3       9fans <plan9-fans@cs.psu.edu>  Fri, 09 Apr 1993 14:29:43 -0400
# 4           melvin@groucho.cs.psu.edu  Fri, 09 Apr 1993 21:31:58 -0800
# ...

# %%
import pandas as pd

df = pd.read_csv("TREC_07.csv", engine="python", on_bad_lines="skip")
df.head(10)
# Out:
#                                               sender  \
# 0                   Tomas Jacobs <RickyAmes@aol.com>
# 1         Yan Morin <yan.morin@savoirfairelinux.com>
# 2  Sheila Crenshaw <7stocknews@tractionmarketing....
# 3         Stormy Dempsey <vqucsmdfgvsg@ruraltek.com>
# 4         "Christi T. Jernigan" <dcube@totalink.net>
# 5     "Bobby L. Fleming" <zvyrepeated@liselebel.com>
# 6  "B.J. Badisang" <mitigatemicroprocessor@g-rich...
# 7                    Real Loss <fibond@terra.com.do>
# 8                    "Jochen.F" <jjfahr@ucalgary.ca>
# 9                        Billy Chin <boxer@0733.com>
#
#                           receiver                             date  \
# 0        the00@speedy.uwaterloo.ca  Sun, 08 Apr 2007 21:00:48 +0300
# 1  debian-mirrors@lists.debian.org  Sun, 08 Apr 2007 12:52:30 -0400
# 2           the00@plg.uwaterloo.ca  Sun, 08 Apr 2007 17:12:19 +0000
# 3         opt4@speedy.uwaterloo.ca  Sun, 08 Apr 2007 17:15:47 -0100
# ...
